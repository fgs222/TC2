# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Del circuito se obtienen las siguientes ecuaciones:
#
# $$
# \frac{V_a - V_i}{Z_2} = \frac{V_i - V_b}{Z_3}~(1)~~~~~~~~~~\frac{V_b - V_i}{Z_4} = \frac{V_i}{Z_5}~(2)
# $$

# %% [markdown]
# De (4):
#
# $$
# \frac{V_b}{Z_4} = \frac{V_i}{Z_4} + \frac{V_i}{Z_5}~~\to~~\frac{V_b}{Z_4} = V_i~.~\frac{Z_4 + Z_5}{Z_4.Z_5}~~\to~~V_b = V_i~.~(1 + \frac{Z_4}{Z_5})~(3)
# $$

# %% [markdown]
# De (2):
#
# $$
# \frac{V_a}{Z_2} = \frac{V_i}{Z_2} + \frac{V_i}{Z_3} - \frac{V_b}{Z_3}
# $$

# %% [markdown]
# Remplazando (3) en $V_b$:
#
# $$
# \frac{V_a}{Z_2} = \frac{V_i}{Z_2} + \frac{V_i}{Z_3} - V_i~.~\frac{1}{Z_3}~.~(1 + \frac{Z_4}{Z_5})~~\to~~\frac{V_a}{Z_2} = \frac{V_i}{Z_2} + \frac{V_i}{Z_3} - \frac{V_i}{Z_3} - V_i~.~\frac{Z_4}{Z_3.Z_5}
# $$

# %% [markdown]
# $$
# \frac{V_a}{Z_2} = \frac{V_i}{Z_2} - V_i~.~\frac{Z_4}{Z_3.Z_5}~~\to~~\frac{V_a}{Z_2} = V_i~.~(\frac{1}{Z_2} - \frac{Z_4}{Z_3.Z_5})
# $$

# %% [markdown]
# $$
# \frac{V_a}{Z_2} = V_i~.~\frac{Z_3.Z_5 - Z_2.Z_4}{Z_2.Z_3.Z_5}~~\to~~V_a = V_i~.~\frac{Z_3.Z_5 - Z_2.Z_4}{Z_3.Z_5}~(4)
# $$

# %% [markdown]
# Siendo $Z_1$:
#
# $$
# Z_i = \frac{V_i}{I_i}~~\to~~Z_i = \frac{V_i}{\frac{V_i}{Z_1} - \frac{V_a}{Z_1}}
# $$

# %% [markdown]
# Remplazando (4) en $V_a$:
#
# $$
# Z_i = \frac{V_i}{I_i}~~\to~~Z_i = \frac{V_i}{\frac{V_i}{Z_1} - \frac{V_i}{Z_1}~.~\frac{Z_3.Z_5 - Z_2.Z_4}{Z_3.Z_5}}
# $$

# %% [markdown]
# $$
# Z_i = \frac{V_i}{V_i~.~\frac{Z_3.Z_5 + Z_2.Z_4 - Z_3.Z_5}{Z_1.Z_3.Z_5}}~~\to~~Z_i = \frac{Z_1.Z_3.Z_5}{Z_2.Z_4}
# $$

# %% [markdown]
# Siendo:
#
# $$
# Z_1 = Z_3 = Z_4 = Z_5 = 1 k\Omega~~~~~~Z_2 = 1\mu F
# $$

# %% [markdown]
# Remplazando en $Z_i$:
#
# $$
# Z_i = \frac{1 k\Omega . 1 k\Omega . 1 k\Omega}{\frac{1}{s.1\mu F} . 1 k\Omega}~~\to~~Z_i = s . 1\mu F . 1 M\Omega^2
# $$

# %% [markdown]
# $$
# Z_i = s . 1 H
# $$

# %%
import numpy
from matplotlib import pyplot as plt
